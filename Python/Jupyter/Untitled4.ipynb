# %%
import pandas as pd

# %%
dataset = pd.read_csv('/home/yago/Projects/Jupyter/analisedados/kaggle_medical.csv', sep=',')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset[dataset['price']==221900.0]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0        1.0
# 10205    40000228  20141015T000000  221900.0       2.0        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 0             1180      5650     1.0           0     0     ...          7
# 10205          780      6727     1.0           0     0     ...          6
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 10205         780              0      1939             0    98168  47.4733
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 10205 -122.281           1860       10124
#
# [2 rows x 21 columns]

# %%
dataset['result'] = (dataset['price']*40)

# %%
dataset['result']
# Out:
# 0         8876000.0
# 1        21520000.0
# 2         7200000.0
# 3        24160000.0
# 4        20400000.0
# 5        49000000.0
# 6        10300000.0
# 7        11674000.0
# 8         9180000.0
# 9        12920000.0
# 10       26500000.0
# 11       18720000.0
# 12       12400000.0
# 13       16000000.0
# 14       21200000.0
# 15       26000000.0
# 16       15800000.0
# 17       19400000.0
# 18        7560000.0
# 19        9200000.0
# 20       15400000.0
# 21       80000000.0
# 22       11400000.0
# 23       10108000.0
# 24       13160000.0
# 25        9320000.0
# 26       37480000.0
# 27       26680000.0
# 28       17520000.0
# 29       28760000.0
#             ...
# 21583    15998000.0
# 21584    15200000.0
# 21585    10800000.0
# 21586    20200000.0
# 21587    15400000.0
# 21588    16580000.0
# 21589    13900000.0
# 21590    48900000.0
# 21591    22880000.0
# 21592    19000000.0
# 21593    43520000.0
# 21594    14000000.0
# 21595    20800000.0
# 21596    27198000.0
# ...

# %%
dataset.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         4
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           1
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
# %matplotlib notebook
dataset['bedrooms'].plot(x='price', color='blue', title='Preço', kind='line')
# Out:
# <img src="data:image/png;base64,..." width="974">
